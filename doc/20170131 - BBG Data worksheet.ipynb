# %% [markdown]
# # BBG Data
#
# Back to 1990.
#
# * MSA-level home prices
# * Yield Curve (10Y, 2Y)
# * CPI
# * 30Y, 15Y generic Mtg rates

# %%
import os
os.chdir("../")
import prepayments

# %%
bbg = prepayments.Bloomberg()

# %%
cpr = bbg.get_cpr("36202K6V2")

# %%
cpr
# Out:
# 1996-09-01   -2.424536e-14
# 1996-10-01    3.000000e-02
# 1996-11-01    1.465000e+01
# 1996-12-01    9.360000e+00
# 1997-01-01    7.540000e+00
# 1997-02-01    3.000000e-02
# 1997-03-01    4.530000e+00
# 1997-04-01    1.020000e+00
# 1997-05-01    5.990000e+00
# 1997-06-01    2.481000e+01
# 1997-07-01    2.318000e+01
# 1997-08-01    1.719000e+01
# 1997-09-01    9.800000e-01
# 1997-10-01    3.677000e+01
# 1997-11-01    2.257000e+01
# 1997-12-01    1.340000e+01
# 1998-01-01    5.730000e+01
# 1998-02-01    6.916000e+01
# 1998-03-01    6.039000e+01
# 1998-04-01    4.264000e+01
# 1998-05-01    9.040000e+00
# 1998-06-01    6.258000e+01
# 1998-07-01    3.800000e+01
# 1998-08-01    8.211000e+01
# 1998-09-01    7.078000e+01
# 1998-10-01    3.685000e+01
# 1998-11-01    2.769000e+01
# 1998-12-01    6.000000e-02
# 1999-01-01    1.676000e+01
# 1999-02-01    8.022000e+01
#                   ...
# 2014-09-01    0.000000e+00
# 2014-10-01    0.000000e+00
# 2014-11-01    0.000000e+00
# ...

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
cpr.plot()

# %%
cpr.cumsum().plot()
